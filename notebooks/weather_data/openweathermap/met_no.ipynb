# %% [markdown]
# Imports

# %%
from metno_locationforecast import Place, Forecast

# %% [markdown]
# Forecast

# %%
new_york = Place("New York", 40.7, -74.0, 10)
ny_forecast = Forecast(new_york, "testapp test123")

ny_forecast.update()
print(ny_forecast)
# Out:
# Forecast for New York:
# 	Forecast between 2023-05-26 13:00:00 and 2023-05-26 14:00:00:
# 		air_pressure_at_sea_level: 1025.7hPa
# 		air_temperature: 15.8celsius
# 		cloud_area_fraction: 0.0%
# 		relative_humidity: 54.1%
# 		wind_from_direction: 10.8degrees
# 		wind_speed: 3.5m/s
# 		precipitation_amount: 0.0mm
# 	Forecast between 2023-05-26 14:00:00 and 2023-05-26 15:00:00:
# 		air_pressure_at_sea_level: 1025.6hPa
# 		air_temperature: 17.3celsius
# 		cloud_area_fraction: 0.0%
# 		relative_humidity: 42.2%
# 		wind_from_direction: 17.5degrees
# 		wind_speed: 3.2m/s
# 		precipitation_amount: 0.0mm
# 	Forecast between 2023-05-26 15:00:00 and 2023-05-26 16:00:00:
# 		air_pressure_at_sea_level: 1025.5hPa
# 		air_temperature: 18.4celsius
# 		cloud_area_fraction: 0.0%
# 		relative_humidity: 38.8%
# 		wind_from_direction: 16.7degrees
# 		wind_speed: 2.9m/s
# 		precipitation_amount: 0.0mm
# 	Forecast between 2023-05-26 16:00:00 and 2023-05-26 17:00:00:
# ...
